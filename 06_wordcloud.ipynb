# %% [markdown]
# # 06 Worldcloud
#
# #### Anvend WordCloud for at konkludere, hvilke ord der fremtræder oftes for hver rating.

# %%
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt

stopwords = set(stopwords.words('danish'))
stopwords.update(['asos','dagd','d','000kr','dk',"com'",'com','m','edit','110kr',"'",'dvs','dag','ca','den11','100kr',
                  'p','o','b','så','kr','kan','få','altid','se','fik','får','ved','lige','haft','to','står','igen','nok',
                  'kun','før','fået','derfor','helt','gange','andet','ellers','ny','bare','kom','par','komplett'
    ])

# %% [markdown]
# ### Functions

# %%
def showWordCloud(filename):

    df = pd.read_csv('./data/'+ filename + '.csv')

    df.columns = ["rating", "review"]

    labels = ['__label__1 ','__label__2 ','__label__3 ','__label__4 ','__label__5 ']
    
    for counter,i in enumerate(labels):

        label = df[df['rating'].isin([i])]
        
        print('Label:', counter +1 )
        rawlist = list(label.review)
        rawlist = str(rawlist)

        word_tokens = word_tokenize(rawlist)

        filtered_sentence = [w for w in word_tokens]

        for w in word_tokens:
            if w not in stopwords:
                filtered_sentence.append(w)

        words =' '.join(str(item) for item in filtered_sentence)

        #CREATE NEW WORDCLOUD WITH NEW SENTENCE WITH REMOVED STOPWORDS
        wordcloud = WordCloud(stopwords=stopwords).generate(words)
        plt.figure(figsize=(10,15))
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        plt.show()

# %% [markdown]
# ### Execute

# %%
showWordCloud('komplett')
# Out:
# Label: 1
# Label: 2
# Label: 3
# Label: 4
# Label: 5
